# %%
from scipy import signal
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
from bokeh.layouts import row
import numpy as np
import math
import sympy as sy
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e81394f-6e1b-4d92-9353-24799e182188">Loading BokehJS ...</span>
#     </div>

# %%
def lti_to_sympy(lsys, symplify=True):
    """ Convert Scipy's LTI instance to Sympy expression """
    s = sy.Symbol('s')
    G = sy.Poly(lsys.num, s) / sy.Poly(lsys.den, s)
    return sy.simplify(G) if symplify else G


def sympy_to_lti(xpr, s=sy.Symbol('s')):
    """ Convert Sympy transfer function polynomial to Scipy LTI """
    num, den = sy.simplify(xpr).as_numer_denom()  # expressions
    p_num_den = sy.poly(num, s), sy.poly(den, s)  # polynomials
    c_num_den = [sy.expand(p).all_coeffs() for p in p_num_den]  # coefficients
    l_num, l_den = [sy.lambdify((), c)() for c in c_num_den]  # convert to floats
    return signal.lti(l_num, l_den)


def polyphase_iir_to_ba_coeffs(directCoeffs,delayedCoeffs):
    #For z^-1:
    z_1 = sy.Symbol('z_1')
    directPath = 1
    delayedPath = 1
    for c in directCoeffs:
        directPath = directPath * (sy.Poly([1,0,c], z_1) / sy.Poly([c,0,1], z_1))
    for c in delayedCoeffs:
        delayedPath = delayedPath * (sy.Poly([1,0,c], z_1) / sy.Poly([c,0,1], z_1))
        
    tranferFunction = 0.5 *( directPath + sy.Poly([1,0], z_1) * delayedPath)
    n,d = sy.fraction(sy.simplify(tranferFunction))
    b = [float(c) for c in sy.Poly(n).all_coeffs()]
    a = [float(c) for c in sy.Poly(d).all_coeffs()]
    return b,a

""" Adapted from:
    Digital signal processing schemes for efficient interpolation and decimation
    R.A. Velenzuela, A.G. Constantinides
    IEEE 1983
    
    transitionBandwitdth between 0 and 0.5 ( 0.5 = half nyquist)
    stopbandAttenuation in dB
"""
def design_polyphase_halfband_iir(transitionBandwidth, stopbandAttenuation):
    k = np.tan((np.pi-2*np.pi*transitionBandwidth)/4)**2
    kp = np.sqrt(1-k**2)
    e = 0.5 * (1 -np.sqrt(kp))/(1+np.sqrt(kp))
    q = e + 2*e**5 + 15*e**9 + 150*e**13
    ds = 10**(-stopbandAttenuation/20)
    k1 = ds**2 / (1 - ds**2)
    n = int(math.ceil(math.log(k1**2/16)/math.log(q)))
    if n % 2 ==0:
        n += 1
    if n ==1 :
        n = 3
    print("Order: %d" % n)
    q1 = q**n
    k1 = 4 * math.sqrt(q1)
    ds = math.sqrt(k1 / (1+k1))
    dp = 1 - math.sqrt(1-ds**2)
    
    def ellipticSum1(q,n,i):
        s = 0
        for m in range(5):
            s += (-1)**m *q**(m*(m+1)) * math.sin((2*m+1)*(math.pi*i)/n)
        return s
    def ellipticSum2(q,n,i):
        s = 0
        for m in range(1,5):
            s += (-1)**m *q**(m*m) * math.cos(2*m*(math.pi*i)/n)
        return s
    wi = [ 2*math.pow(q,0.25) * ellipticSum1(q,n,i)/(1+2*ellipticSum2(q,n,i)) for i in range(1,int((n-1)/2)+1) ]
    ai = [ math.sqrt((1-(w**2)*k)*(1-(w**2)/k))/(1+w**2) for w in wi ]
    ai = [ (1-a)/(1+a) for a in ai ]
    #print(ai)
    return ai[0::2], ai[1::2]

# %%
def plot_filter(b,a,name):
    p1 = figure(plot_width = 500, plot_height=300, title = "%s Gain" % name, y_range = (-80,6))
    p1.xaxis.axis_label = 'Frequency [rad/sample]'
    p1.yaxis.axis_label = 'Amplitude [dB]'
    w, h = signal.freqz(b,a)
    p1.line(w, 20 * np.log10(abs(h)))
    
    w, gd = signal.group_delay((b, a))
    p2 = figure(plot_width = 500, plot_height=300, title = "%s Group delay" % name)
    p2.xaxis.axis_label = 'Frequency [rad/sample]'
    p2.yaxis.axis_label = 'Group delay [samples]'
    p2.line(w,gd)
    show(row(p1,p2))

# %%
#b, a = signal.iirdesign(0., 0.3, 5, 50, ftype='cheby1')
b,a  = signal.cheby1(5,1,0.5)
np.set_printoptions(precision=16)
#print(a)
#print(b)
plot_filter(b,a,'Cheby1')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d45044c6-afc2-420f-aa81-30bc61023c93"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d45044c6-afc2-420f-aa81-30bc61023c93");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d45044c6-afc2-420f-aa81-30bc61023c93");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd45044c6-afc2-420f-aa81-30bc61023c93' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"69e2b2ad-8ff1-424d-b2d9-00d254fc5c52":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"84b71e81-edd2-40f0-951d-2c92497fef6a","type":"Line"},{"attributes":{},"id":"49348384-33d6-4262-9467-b6d85fc4b44c","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"93d3446a-24e9-462d-9398-5405047ee855","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"a579b3bb-235a-4eed-b44a-19ba4321e949","subtype":"Figure","type":"Plot"},"ticker":{"id":"3cfde66f-fd14-457a-9aa8-9c31fcaccdc8","type":"BasicTicker"}},"id":"3b8b3446-5b7f-4b5d-ac5a-5cb678076c6a","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e08c4e44-7fe2-454e-8cc2-d7bebab18ab5","type":"Line"},{"attributes":{},"id":"f9e164da-976b-4696-af02-a1d3f1849c97","type":"ToolEvents"},{"attributes":{"axis_label":"Amplitude [dB]","formatter":{"id":"54129d8e-d8fb-44f2-9f39-06c176166af6","type":"BasicTickFormatter"},"plot":{"id":"a579b3bb-235a-4eed-b44a-19ba4321e949","subtype":"Figure","type":"Plot"},"ticker":{"id":"3cfde66f-fd14-457a-9aa8-9c31fcaccdc8","type":"BasicTicker"}},"id":"4bf1ac1c-f41d-427d-a4f6-61f983239d1c","type":"LinearAxis"},{"attributes":{},"id":"54129d8e-d8fb-44f2-9f39-06c176166af6","type":"BasicTickFormatter"},{"attributes":{},"id":"2b2e85cf-371f-4c0d-a5cb-edbcc882e224","type":"BasicTicker"},{"attributes":{"data_source":{"id":"d29b45dc-d349-4750-a971-5c723857ef82","type":"ColumnDataSource"},"glyph":{"id":"84b71e81-edd2-40f0-951d-2c92497fef6a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5ffa1cd4-c2d6-4886-9768-0628a226da56","type":"Line"},"selection_glyph":null},"id":"4176cc39-a131-4abb-a7a6-718fcee196a6","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"66b4ab84-e3cd-47a8-9a59-c514d3da22a5","type":"PanTool"},{"id":"e9d67bb7-152e-4167-acf8-4da92d791da6","type":"WheelZoomTool"},{"id":"9a810eb9-ccc3-4430-af0c-f688c584a060","type":"BoxZoomTool"},{"id":"7538758e-e628-4740-9650-284371877739","type":"SaveTool"},{"id":"7e8eae1f-c992-4a3c-a440-fa70dc53386f","type":"ResetTool"},{"id":"7f055219-898d-4563-a98a-27158a5c4609","type":"HelpTool"}]},"id":"23980c3b-265e-4d04-8948-41fdff5e3c73","type":"Toolbar"},{"attributes":{"plot":null,"text":"Cheby1 Group delay"},"id":"ee4eb46d-818a-4c45-bde2-e3640f7204c4","type":"Title"},{"attributes":{"plot":null,"text":"Cheby1 Gain"},"id":"b918
type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8134dc25-101e-4446-aaac-c2882d98ba26","type":"Line"},"selection_glyph":null},"id":"48abb1b6-971f-4073-bf9a-cbbd1d01b422","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e79b290-99de-4bdc-a933-e80060e32d4c","type":"Line"},{"attributes":{"below":[{"id":"9357fe07-db1c-4a24-9a80-37fc98099d86","type":"LinearAxis"}],"left":[{"id":"8e1e8b2d-3d37-4eb4-ae77-ee22dd828b69","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"9357fe07-db1c-4a24-9a80-37fc98099d86","type":"LinearAxis"},{"id":"2965e829-31a1-4973-b257-09d080292be9","type":"Grid"},{"id":"8e1e8b2d-3d37-4eb4-ae77-ee22dd828b69","type":"LinearAxis"},{"id":"63aaa470-1839-4025-ac54-a98c1b212e76","type":"Grid"},{"id":"8ccfc8d7-24e8-4772-9179-8e4413846af7","type":"BoxAnnotation"},{"id":"48abb1b6-971f-4073-bf9a-cbbd1d01b422","type":"GlyphRenderer"}],"title":{"id":"4de5411a-4997-479c-b0f9-340b25ce0657","type":"Title"},"tool_events":{"id":"a004cb4d-a4d5-43a3-aaa6-d05f589b1a2e","type":"ToolEvents"},"toolbar":{"id":"75b8d8bc-162c-44ea-9ecf-15b31b9c114a","type":"Toolbar"},"x_range":{"id":"1c04ee5b-d2ae-4aca-b27a-b7e46db39f99","type":"DataRange1d"},"y_range":{"id":"796e1075-e057-48c5-80f8-9d442cacd987","type":"Range1d"}},"id":"b1c25a54-df3d-4c53-b9a7-caf5e7e832ca","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Amplitude [dB]","formatter":{"id":"75b03135-2203-4911-8bf7-10c55d831054","type":"BasicTickFormatter"},"plot":{"id":"b1c25a54-df3d-4c53-b9a7-caf5e7e832ca","subtype":"Figure","type":"Plot"},"ticker":{"id":"d520de07-1c1c-4ce9-a78f-4282da9f3864","type":"BasicTicker"}},"id":"8e1e8b2d-3d37-4eb4-ae77-ee22dd828b69","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[512]},"y":{"__ndarray__":"...","dtype":"float64","shape":[512]}}},"id":"717ccb81-8784-4b3c-9f0d-74ffceb99497","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"2e579477-001f-41dd-8e60-0aecc8f386b3","type":"LinearAxis"}],"left":[{"id":"35a4d532-7790-40c7-8228-a65284e8ef3a","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"2e579477-001f-41dd-8e60-0aecc8f386b3","type":"LinearAxis"},{"id":"65d4f97e-4d6d-4d67-be9c-d01fef2b944c","type":"Grid"},{"id":"35a4d532-7790-40c7-8228-a65284e8ef3a","type":"LinearAxis"},{"id":"722a794b-777c-47d7-aeaf-b12b3ec3d8f6","type":"Grid"},{"id":"98e0df12-a21e-4258-a714-3125cc211f81","type":"BoxAnnotation"},{"id":"1cbf41cc-2b28-4aab-8050-a740832d276c","type":"GlyphRenderer"}],"title":{"id":"89916d18-d6a5-473c-8e8f-d4164229de5c","type":"Title"},"tool_events":{"id":"4727da73-672a-49cf-b5bf-e9f96cf8b98d","type":"ToolEvents"},"toolbar":{"id":"09cddb9c-7ad4-4361-8d88-8b06c1f28c83","type":"Toolbar"},"x_range":{"id":"1618d192-cb21-4ce1-a409-ad0dfe6781dd","type":"DataRange1d"},"y_range":{"id":"5c3c0310-b576-4935-9231-0aa4f4319abf","type":"DataRange1d"}},"id" ...

# %%
b,a = polyphase_iir_to_ba_coeffs([1.0 / (5 + 2 * np.sqrt(5))],[5-2*np.sqrt(5)])
plot_filter(b,a,'ButterPolyphase')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5f52cb6a-6331-4795-b4a1-68e646923885"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5f52cb6a-6331-4795-b4a1-68e646923885");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5f52cb6a-6331-4795-b4a1-68e646923885");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5f52cb6a-6331-4795-b4a1-68e646923885' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"21d37a7a-9e0f-415c-86e8-685f40e4b15c":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"16de8459-0838-4481-a44c-cfdc77a039e7","type":"Line"},{"attributes":{"below":[{"id":"848db849-abea-4372-86e6-034885cf6459","type":"LinearAxis"}],"left":[{"id":"2f983ecb-adf7-44f2-9ce2-862a198ce54f","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"848db849-abea-4372-86e6-034885cf6459","type":"LinearAxis"},{"id":"8b06fef2-79ed-444f-98ef-2e29118f12c9","type":"Grid"},{"id":"2f983ecb-adf7-44f2-9ce2-862a198ce54f","type":"LinearAxis"},{"id":"a64b9c51-1594-46d7-8df7-b53eb6ae0738","type":"Grid"},{"id":"dd857cc2-a82e-45da-b720-04054e66d1c6","type":"BoxAnnotation"},{"id":"546eab80-0fe8-4ea5-b6a0-19134cf00628","type":"GlyphRenderer"}],"title":{"id":"7c79815d-194e-465f-b354-2fb8499d61fd","type":"Title"},"tool_events":{"id":"bce44705-277e-4681-afc0-6133f87611f7","type":"ToolEvents"},"toolbar":{"id":"8d9ac900-876a-45da-9fca-630b3cd008b5","type":"Toolbar"},"x_range":{"id":"8425ee96-23b6-47a7-80ec-429b3d19c956","type":"DataRange1d"},"y_range":{"id":"e183dc92-e17e-4375-abeb-ba3bcc282e1b","type":"Range1d"}},"id":"7f0640a0-8cf3-4ffd-a473-9ff3604a9c76","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"fe29991f-01ae-489f-bba3-ff74ac87e4b3","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"7f0640a0-8cf3-4ffd-a473-9ff3604a9c76","subtype":"Figure","type":"Plot"},{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"}]},"id":"0f348df2-796b-46cc-8fa7-563ebb8bcdd0","type":"Row"},{"attributes":{"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"}},"id":"58e4d3a7-0a77-4f6a-b21f-8854e555bc4a","type":"HelpTool"},{"attributes":{"axis_label":"Frequency [rad/sample]","formatter":{"id":"740f9896-5701-418a-a99d-70b7bcc4cfcd","type":"BasicTickFormatter"},"plot":{"id":"7f0640a0-8cf3-4ffd-a473-9ff3604a9c76","subtype":"Figure","type":"Plot"},"ticker":{"id":"e36c979d-ba10-4095-93dc-ab32331fc4af","type":"BasicTicker"}},"id":"848db849-abea-4372-86e6-034885cf6459","type":"LinearAxis"},{"attributes":{"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"}},"id":"142f5008-6e7c-4bca-b746-ed9a2a09c9b6","type":"SaveTool"},{"attributes":{"overlay":{"id":"6ff9b4c3-cde2-4521-af42-329339284d42","type":"BoxAnnotation"},"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"}},"id":"e1671a5d-eebf-42de-a87c-6f19716dd416","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"}},"id":"af25ffce-018c-433d-82a2-80164a0090aa","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"dd857cc2-a82e-45da-b720-04054e66d1c6","type":"BoxAnnotation"},"plot":{"id":"7f0640a0-8cf3-4ffd-a473-9ff3604a9c76","subtype":"Figure","type":"Plot"}},"id":"35d2534a-bef3-481f-87e2-c955bb27ebd3","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"}},"id":"935da721-5a19-458e-bc5d-72e8a9224494","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f83b18f1-df44-44cf-8461-a42454e0c97b","type":"Line"},{"attributes":{"axis_label":"Frequency [rad/sample]","formatter":{"id":"fe29991f-01ae-489f-bba3-ff74ac87e4b3","type":"BasicTickFormatter"},"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b363a67-3faa-4e40-b23f-e0489466e913","type":"BasicTicker"}},"id":"eed316a6-8311-4cd8-b80d-9867fd02532e","type":"LinearAxis"},{"attributes":{"callback":null,"end":6,"start":-80},"id":"e183dc92-e17e-4375-abeb-ba3bcc282e1b","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"092f4630-dd56-43da-aa89-9c840c7c61b6","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ea17afb-b49f-4961-b7b1-7252481ce0a8","type":"BasicTicker"}},"i ...

# %%
int(math.ceil(0.9))
# Out:
# 1

# %%
directCoeffs,delayedCoeffs = design_polyphase_halfband_iir(0.1, 30)
print(directCoeffs)
print(delayedCoeffs)
b,a = polyphase_iir_to_ba_coeffs(directCoeffs,delayedCoeffs)
plot_filter(b,a,'Cheby-ish polyphase')
# Out:
# Order: 5
# [0.23647102099689202]
# [0.71454214971259888]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="06d3c9f5-bb0c-4512-a26d-8fad771d30e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("06d3c9f5-bb0c-4512-a26d-8fad771d30e6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("06d3c9f5-bb0c-4512-a26d-8fad771d30e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '06d3c9f5-bb0c-4512-a26d-8fad771d30e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"80d4fd8f-4a31-4648-98d1-8f2a05927cb8":{"roots":{"references":[{"attributes":{"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"},"ticker":{"id":"51916f43-c989-4555-85ea-1dc5d714df3e","type":"BasicTicker"}},"id":"e8b252c5-4e8d-41c0-b7e2-f6cbc4d7b9a5","type":"Grid"},{"attributes":{"axis_label":"Frequency [rad/sample]","formatter":{"id":"ba379145-c3fd-43ac-8b0f-731c23575ed9","type":"BasicTickFormatter"},"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"},"ticker":{"id":"51916f43-c989-4555-85ea-1dc5d714df3e","type":"BasicTicker"}},"id":"7c856ea3-804c-4e6c-a41b-3fe041f73ad5","type":"LinearAxis"},{"attributes":{"axis_label":"Frequency [rad/sample]","formatter":{"id":"c5a3402a-9bb3-4bb3-b001-9d6f7373c04f","type":"BasicTickFormatter"},"plot":{"id":"79632afc-17a3-4f64-9518-240b8c91d1c2","subtype":"Figure","type":"Plot"},"ticker":{"id":"39961597-439f-4914-83b5-8ad62a329a82","type":"BasicTicker"}},"id":"8c22168e-2919-4213-87d5-a22fdc56d411","type":"LinearAxis"},{"attributes":{"plot":{"id":"79632afc-17a3-4f64-9518-240b8c91d1c2","subtype":"Figure","type":"Plot"}},"id":"71423be8-ded1-413d-bd7f-8fcf5ec36bca","type":"PanTool"},{"attributes":{},"id":"39961597-439f-4914-83b5-8ad62a329a82","type":"BasicTicker"},{"attributes":{"callback":null,"end":6,"start":-80},"id":"b6b5e59a-4e84-4ca4-bf90-ad1703fd8d06","type":"Range1d"},{"attributes":{"plot":{"id":"79632afc-17a3-4f64-9518-240b8c91d1c2","subtype":"Figure","type":"Plot"}},"id":"c99b8324-4213-4414-af62-f71880673781","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"79632afc-17a3-4f64-9518-240b8c91d1c2","subtype":"Figure","type":"Plot"},"ticker":{"id":"09e36681-2e90-417c-8033-e86a88c73764","type":"BasicTicker"}},"id":"631098f5-cece-4a15-8a01-dbbfd6854691","type":"Grid"},{"attributes":{},"id":"86dc55dd-95b6-43d0-bf1b-03b7348e1102","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"}},"id":"04df7f55-4515-48cb-b9d4-e1f24bb56162","type":"ResetTool"},{"attributes":{"callback":null},"id":"f4985909-b18e-4e50-aeb3-086078812962","type":"DataRange1d"},{"attributes":{},"id":"c5a3402a-9bb3-4bb3-b001-9d6f7373c04f","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"150e0713-1e5b-409a-b89c-0421237b4fed","type":"ColumnDataSource"},"glyph":{"id":"679f50d0-c4a1-4ad1-9dc0-bba286ad7408","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3fbbe7c6-e2b4-46f0-8221-098f0eb3c54b","type":"Line"},"selection_glyph":null},"id":"54a37908-277a-4314-af43-633328d9f12b","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"}},"id":"5567e1df-23a6-4a6c-bbb6-e6176e466ccb","type":"PanTool"},{"attributes":{"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"}},"id":"e370348e-5a7e-4b30-9944-0e3b89030fa5","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"bb5dbb54-661d-494c-9685-4dff9e208f7f","type":"DataRange1d"},{"attributes":{},"id":"efdc0674-3533-4cd3-b6ae-bc10943441c1","type":"ToolEvents"},{"attributes":{"plot":{"id":"79632afc-17a3-4f64-9518-240b8c91d1c2","subtype":"Figure","type":"Plot"}},"id":"e935d659-1e77-4053-b924-8de6b2255b9e","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"Cheby-ish polyphase Group delay"},"id":"c92f788a-0c6b-4771-86ae-887342505e65","type":"Title"},{"attributes":{},"id":"dff9610d-684e-4247-8c26-02ed99236138","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"8ce7e8d4-aba1-46a8-a361-76d4877d6ba3","type":"BoxAnnotation"},"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"}},"id":"1751776e-d79d-4501-a7bb-6e2ce752909b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"0e330379-a7c0-4dc6-a46a-5ad27e0e5b48","subtype":"Figure","type":"Plot"}},"id":"188b63ba-af3c-416d-b8ba-ba0a684b281e","type":"SaveTool"},{"attributes":{"overl ...

# %%
[i for i in range(1,int((7-1)/2)+1)]
# Out:
# [1, 2, 3]

# %%
[1.0 / (5 + 2 * np.sqrt(5))],[5-2*np.sqrt(5)]
# Out:
# ([0.10557280900008412], [0.52786404500042039])
